# %% [markdown]
# This is my python notes

# %%
#importing pandas

#Ctrl + / for commenting
import pandas as pd

# %%
#Creating dataframe . Reading csv file using read_csv method
df=pd.read_csv("Data\survey_results_public.csv")
schema_df=pd.read_csv("C:\Users\SHETTS60\Documents\Python scripts\Data\survey_results_schema.csv")

# %%
#Gives count of rows,columns. Shape is an attribute hence "()" is not used
df.shape
# Out:
# (64461, 61)

# %%
#Gives count of rows,columns and datatype. Info is a method hence "()" is  used
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
# Respondent                      64461 non-null int64
# MainBranch                      64162 non-null object
# Hobbyist                        64416 non-null object
# Age                             45446 non-null float64
# Age1stCode                      57900 non-null object
# CompFreq                        40069 non-null object
# CompTotal                       34826 non-null float64
# ConvertedComp                   34756 non-null float64
# Country                         64072 non-null object
# CurrencyDesc                    45472 non-null object
# CurrencySymbol                  45472 non-null object
# DatabaseDesireNextYear          44070 non-null object
# DatabaseWorkedWith              49537 non-null object
# DevType                         49370 non-null object
# EdLevel                         57431 non-null object
# ...

# %%
#set the max columns to display . To set rows, just replace columns with row in the below code
pd.set_option("display.max_columns",85)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
# head method is used to display first values.By deafult its 5. You can gives no of rows to be printed inside "()"
df.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
#
#   CompFreq  CompTotal  ConvertedComp         Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN         Germany   European Euro
# 1      NaN        NaN            NaN  United Kingdom  Pound sterling
#
#       ...                       SurveyEase           SurveyLength Trans  \
# 0     ...       Neither easy nor difficult  Appropriate in length    No
# 1     ...                              NaN                    NaN   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
#
#      WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# ...

# %%
# tail method is used to display last values.By deafult its 5. You can gives no of rows to be printed inside "()"
df.tail(2)
# Out:
#        Respondent MainBranch Hobbyist              OpenSourcer  \
# 88881       88816        NaN       No                    Never
# 88882       88863        NaN      Yes  Less than once per year
#
#                                               OpenSource  \
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment Country  \
# 88881  Independent contractor, freelancer, or self-em...     NaN
# 88882             Not employed, and not looking for work   Spain
#
#               Student                             EdLevel  \
# 88881             NaN                                 NaN
# 88882  Yes, full-time  Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
# ...

# %%
#Creating Dummy dictionary. Creating list in dictionary
Details = { 
    'Name' : ['shishirshetty','Shir','Shir'],
    'Email' : ['shishirshetty@gmail.com','Shir@gmail.com','Shetty@gmail.com'],
    'Phone':[100,101,102]
}
#Assigning Dictionary to new Df
import pandas as pd
newdf = pd.DataFrame(Details)

# %%
#printing only 'name' column of newdf . You can use do it 2 ways
newdf['Name']
#or
newdf.Name
# Out:
# 0    shishirshetty
# 1             Shir
# 2             Shir
# Name: Name, dtype: object

# %%
#printing  'name', 'Email' column of newdf  together. 
#If we want to print more than one row or more than one column together make use of list ie. []
newdf[['Name','Email']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d8261513ce90> in <module>()
#       1 #printing  'name', 'Email' column of newdf  together.
#       2 #If we want to print more than one row or more than one column together make use of list ie. []
# ----> 3 newdf[['Name','Email']]
#
# NameError: name 'newdf' is not defined

# %%
#Get all the column names
newdf.columns
# Out:
# Index(['Email', 'Name', 'Phone'], dtype='object')

# %%
#'iloc' is used to access the particular by giving the Index of the row inside '[]'. iloc stands for index location
newdf.iloc[0]
# Out:
# Email    shishirshetty@gmail.com
# Name               shishirshetty
# Phone                        100
# Name: 0, dtype: object

# %%
#printing 2 rows together
newdf.iloc[[0,1]]
# Out:
#                      Email           Name  Phone
# 0  shishirshetty@gmail.com  shishirshetty    100
# 1           Shir@gmail.com           Shir    101

# %%
#we can print the specified rows and columns using their indexes. [[0,1],1], where[0,1] is the row index and 1 is the column index
newdf.iloc[[0,1],1]
# Out:
# 0    shishirshetty
# 1             Shir
# Name: Name, dtype: object

# %%
#In 'iloc' we use index to print rows and columns, but in 'loc' we used index for rows and labels for columns.
#we can print the specified rows and columns using their indexes. [[0,1],'Email'], where[0,1] is the row index and 'Email' is the column label
newdf.loc[[0,1],'Email']
# Out:
# 0    shishirshetty@gmail.com
# 1             Shir@gmail.com
# Name: Email, dtype: object

# %%
#printing 2 rows and 2 columns together.[0,1] is the row index.['Name','Email'] is the column label
newdf.loc[[0,1],['Name','Email']]
# Out:
#             Name                    Email
# 0  shishirshetty  shishirshetty@gmail.com
# 1           Shir           Shir@gmail.com

# %%
#printing 2 rows together by using list slicer i.e,0:1. when you use slicer dont make us of '[]'
newdf.loc[0:1,['Name']]
# Out:
#             Name                    Email  Phone
# 0  shishirshetty  shishirshetty@gmail.com    100
# 1           Shir           Shir@gmail.com    101

# %%
#printing 2 columns together by using list slicer i.e, 'Name':'Phone'. when you use slicer dont make us of '[]'
newdf.loc[0:1,'Name':'Phone']
# Out:
#             Name  Phone
# 0  shishirshetty    100
# 1           Shir    101

# %%
#Setting index as 'Phone'.this wont permanently set it.
newdf.set_index("Phone")
# Out:
#                          Email           Name
# Phone
# 100    shishirshetty@gmail.com  shishirshetty
# 101             Shir@gmail.com           Shir
# 102           Shetty@gmail.com           Shir

# %%
#Setting index as 'Phone'.this will permanently set it by using 'inplace'.
newdf.set_index("Phone", inplace=True)
newdf
#After setting index permanently we can no longer access using index in 'loc'. to access using index we have to use 'iloc'
#Always first analyse the data and identify the column that can be set as index
# Out:
#                 Name                    Email
# Phone
# 100    shishirshetty  shishirshetty@gmail.com
# 101             Shir           Shir@gmail.com
# 102           Shetty         Shetty@gmail.com

# %%
#'reset_index' is used to reset the index to default
newdf.reset_index(inplace=True)
newdf
# Out:
#    Phone           Name                    Email
# 0    100  shishirshetty  shishirshetty@gmail.com
# 1    101           Shir           Shir@gmail.com
# 2    102         Shetty         Shetty@gmail.com

# %%
#setting the 'column' as index.
schema_df.set_index('Column',inplace=True)
#Accessing one of the value(row) of Index column using loc
schema_df.loc['Hobbyist']
# Out:
# index                                 2
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
#sort the index in ascending order. for descending order make 'ascending = false'
schema_df.sort_index(ascending=True)
# Out:
#                index                                       QuestionText
# Column
# Age               77  What is your age (in years)? If you prefer not...
# Age1stCode        14  At what age did you write your first line of c...
# BetterLife        58  Do you think people born today will have a bet...
# BlockchainIs      57  Blockchain / cryptocurrency technology is prim...
# BlockchainOrg     56  How is your organization thinking about or imp...
# ...              ...                                                ...
# WorkPlan          33            How structured or planned is your work?
# WorkRemote        35                    How often do you work remotely?
# WorkWeekHrs       32   On average, how many hours per week do you work?
# YearsCode         13  Including any education, how many years have y...
# YearsCodePro      15  How many years have you coded professionally (...
#
# [85 rows x 2 columns]

# %%
#Filtering. First assign the filter condition to one of the variale('filt') and then print it
filt = (newdf['Name']=='Shir')
newdf[filt]
#Also can pass the filter variable to 'loc' to get the particular column.Below code give result with only 'Phone' Column.
newdf.loc[filt,'Phone']
# Out:
# 1    101
# 2    102
# Name: Phone, dtype: int64

# %%
#AND operator '&'
filt = (newdf['Name']=='Shir') & (newdf['Phone']==101)
newdf.loc[filt,'Email']

#OR operator  '|'
filt = (newdf['Name']=='Shir') | (newdf['Phone']==101)
newdf.loc[filt,'Email']

#NOT operator '`'
filt = (newdf['Name']=='Shir')
newdf.loc[~filt,'Phone']
# Out:
# 1      Shir@gmail.com
# 2    Shetty@gmail.com
# Name: Email, dtype: object

# %%
#'isin' method is used like 'is present in the'. Create list of countries 'countries' and then apply filter for the dataframe using 'isin'
countries = ['United States','India','United Kingdom']
filt = (df['Country'].isin(countries))
df.loc[filt,'Country']
# Out:
# 0        United Kingdom
# 3         United States
# 7                 India
# 9                 India
# 12        United States
#               ...
# 88854    United Kingdom
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# Name: Country, Length: 35747, dtype: object

# %%
#'str.contains' is one of the string method.'Python' is the string we are matching and 'na' Should be given as false since there might be no values sometime.
filt = (df['LanguageWorkedWith'].str.contains('Python',na= False))
df.loc[filt,['Country','LanguageWorkedWith']]
# Out:
#                       Country  \
# 0              United Kingdom
# 1      Bosnia and Herzegovina
# 3               United States
# 4                     Ukraine
# 7                       India
# ...                       ...
# 88854          United Kingdom
# 88860                  Brazil
# 88865             Switzerland
# 88872          Czech Republic
# 88876                   Spain
#
#                                       LanguageWorkedWith
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                  ...
# 88854  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860    Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865    Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# ...

# %%
#to convert all the columns to Upper case
newdf.columns = (x.upper() for x in newdf.columns)
#to convert all the columns to lower case
newdf.columns = (x.lower() for x in newdf.columns)

# %%
#'replace' is used to rename columns,remove space etc.
newdf.columns = newdf.columns.str.replace('phoNe','Phone')

# %%
#Rename can also done by below method
newdf.rename(columns = {'Name':'NaMe'},inplace = True)

# %%
#to change Values of particular column of particular row can be done by below method
newdf.loc[[2],['Name','Phone']]=['Shishir',103]
newdf
# Out:
#             Name                    Email  Phone
# 0  shishirshetty  shishirshetty@gmail.com    100
# 1           Shir           Shir@gmail.com    101
# 2        Shishir         Shetty@gmail.com    103

# %%
#convert values in the 'Email' column to lower case. To convert into upper case replace 'lower' with 'upper'
newdf['Email'] = newdf['Email'].str.lower()
newdf
# Out:
#             Name                    Email  Phone
# 0  shishirshetty  SHISHIRSHETTY@GMAIL.COM    100
# 1           Shir           SHIR@GMAIL.COM    101
# 2        Shishir         SHETTY@GMAIL.COM    103

# %%
newdf.loc[2,['Name']]='Shishir'
newdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cb5602050601> in <module>()
# ----> 1 newdf.loc[2,['Name']]='Shishir'
#       2 newdf
#
# NameError: name 'newdf' is not defined

# %%
#to find the length of all the rows of 'Email' column.
newdf['Email'].apply(len)
# Out:
# 0    23
# 1    14
# 2    16
# Name: Email, dtype: int64

# %%
#Another method to convert into Upper or lower
#Create a function 'Upper_Email' which takes one argument and converts into upper
def Upper_Email(email):
    return email.upper()
#pass the Function like below.It will convert all the rows in'Email'column to upper.
newdf['Email'] = newdf['Email'].apply(Upper_Email)

# %%
#Another method to convert into Upper or lower using Lambda method
newdf['Email']=newdf['Email'].apply(lambda x:x.lower())
# Out:
#             Name                    Email  Phone
# 0  shishirshetty  shishirshetty@gmail.com    100
# 1           Shir           shir@gmail.com    101
# 2           Shir         shetty@gmail.com    102

# %%
newdf
# Out:
#                      Email           Name  Phone
# 0  shishirshetty@gmail.com  shishirshetty    100
# 1           Shir@gmail.com           Shir    101
# 2         Shetty@gmail.com           Shir    102

# %%
#Instead of using loc or iloc we can make use of simple '.' indicator
Score={
    'Name': ['Hardik','Krunal','Pollard'],
    'Runs': [20,15,45],
    'Ball': [15,13,20]
}
import pandas as pd
df = pd.DataFrame(Score)
df[(df.Name == 'Pollard')].Runs
# Out:
# 2    45
# Name: Runs, dtype: int64

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path="C:\\Users\\SHETTS60\\Documents\\Python scripts\\Cricket analytics Materials\\MSD Analysis\\ipl_ball_by_ball_data.csv"
df = pd.read_csv(path)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = df[(df['innings'] == 1) | (df['innings'] == 2)]

# %%
req_df = df[(df['striker'] == "AB de Villiers")]

# %%
tempdf = pd.DataFrame(req_df["bowler"].unique())

# %%
tempdf
# Out:
#                      0
# 0    MS Gony
# 1    M Ntini
# 2    M Muralitharan
# 3    JA Morkel
# 4    Joginder Sharma
# 5    SM Pollock
# 6    DJ Bravo
# 7    A Nehra
# 8    AD Mascarenhas
# 9    SK Trivedi
# 10   SK Warne
# 11   Shoaib Akhtar
# 12   I Sharma
# 13   AB Dinda
# 14   JH Kallis
# 15   B Akhil
# 16   A Kumble
# 17   DW Steyn
# 18   A Flintoff
# 19   L Balaji
# 20   KP Appanna
# 21   Pankaj Singh
# 22   MM Patel
# 23   Kamran Khan
# 24   YK Pathan
# 25   RA Jadeja
# 26   Shoaib Ahmed
# 27   RP Singh
# 28   S Tyagi
# 29   SL Malinga
# 30   JP Duminy
# 31   SR Tendulkar
# 32   RR Raje
# 33   Harbhajan Singh
# 34   MC Henriques
# 35   M Kartik
# 36   AB Agarkar
# 37   SS Sarkar
# 38   A Symonds
# 39   PP Ojha
# 40   DR Smith
# 41   WPUJC Vaas
# 42   PP Chawla
# 43   S Sreesanth
# 44   RR Powar
# 45   IK Pathan
# 46   AS Raut
# 47   J Botha
# 48   A Singh
# 49   RE van der Merwe
# 50   P Kumar
# 51   RG Sharma
# 52   Harmeet Singh
# 53   YA Abdulla
# 54   SW Tait
# ...

# %%
tempdf.to_csv('ABD_Bowlers.csv', index = False)

# %%
# to convert into dataframes
import pandas as pd

# extract url response/info
from urllib.request import urlopen

# to work with html content
from bs4 import BeautifulSoup

# %%
# find pages count, using page 1 as reference
url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=" + str(1) + ";template=results;type=bowling;view=innings"
text = urlopen(url)
soup = BeautifulSoup(text, "lxml")
table = soup.findAll('table', attrs = {'class' : 'engineTable'})

tr_list = table[1].findAll('tr', attrs = {'class': 'data2'})

min_pages = int(tr_list[0].findAll('b')[0].get_text())
max_pages = int(tr_list[0].findAll('b')[1].get_text())

entries_per_page = int(tr_list[0].findAll('b')[3].get_text())
total_players_count = int(tr_list[0].findAll('b')[4].get_text())

# set limits to run the for loop
min_limit = min_pages
if (total_players_count//entries_per_page) > 0:
    max_limit = max_pages + 1

# initialize all players data
all_players = []

for k in range(min_limit, max_limit):
    # url to text & then to soup object conversion
    url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=" + str(k) + ";template=results;type=bowling;view=innings"
    text = urlopen(url)
    soup = BeautifulSoup(text, "lxml")
    table = soup.findAll('table', attrs = {'class' : 'engineTable'})
    int_table = table[0]
    
    # iterate through all tables, find the one with caption tag
    for temp_table in table:
        caption_tag = temp_table.findAll('caption')
        if(len(caption_tag) > 0):
            int_table = temp_table
    
    # fetch table with data
    tr_list = int_table.findAll('tr', attrs = {'class': 'data1'})
    
    # populate data
    for tr in tr_list:
        td_list = tr.findAll('td')
        row_data = []
        for td in td_list:
            td_str = str(td)
            cleantext = BeautifulSoup(td_str, "lxml").get_text()
            row_data.append(cleantext)
        all_players.append(row_data)
        
    # populate column names
    tr_list_columns = int_table.findAll('tr', attrs = {'class': 'headlinks'})
    cols_count = len(tr_list_columns[0].findAll('th'))
    
    column_names_ls = []
    for i in range(cols_count):
        column_name = tr_list_columns[0].findAll('th')[i].get_text()
        column_names_ls.append(column_name)
        
    # convert to dataframe
    odi_bowl_ing_df = pd.DataFrame(all_players, columns = column_names_ls)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2dbeb965c075> in <module>()
#      24     # url to text & then to soup object conversion
#      25     url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=" + str(k) + ";template=results;type=bowling;view=innings"
# ---> 26     text = urlopen(url)
#      27     soup = BeautifulSoup(text, "lxml")
#      28     table = soup.findAll('table', attrs = {'class' : 'engineTable'})
#
# C:\Program Files\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# C:\Program Files\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# ...

# %%
len(odi_bowl_ing_df)

# %%
odi_bowl_ing_df.to_csv('ABD_Bowlers.csv', index = False)
