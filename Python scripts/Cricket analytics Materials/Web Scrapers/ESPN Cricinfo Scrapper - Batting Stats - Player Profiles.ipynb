# %% [markdown]
# ## Imports

# %%
# to convert into dataframes
import pandas as pd

# extract url response/info
from urllib.request import urlopen

# to work with html content
from bs4 import BeautifulSoup

# %% [markdown]
# ## T20I - Batting Stats - By Players

# %%
# find pages count, using page 1 as reference
url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=" + str(1) + ";template=results;type=batting"
text = urlopen(url)
soup = BeautifulSoup(text, "lxml")
table = soup.findAll('table', attrs = {'class' : 'engineTable'})

tr_list = table[1].findAll('tr', attrs = {'class': 'data2'})

min_pages = int(tr_list[0].findAll('b')[0].get_text())
max_pages = int(tr_list[0].findAll('b')[1].get_text())

entries_per_page = int(tr_list[0].findAll('b')[3].get_text())
total_players_count = int(tr_list[0].findAll('b')[4].get_text())

# set limits to run the for loop
min_limit = min_pages
if (total_players_count//entries_per_page) > 0:
    max_limit = max_pages + 1

# initialize all players data
all_players = []

for k in range(min_limit, max_limit):
    # url to text & then to soup object conversion
    url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=" + str(k) + ";template=results;type=batting"
    text = urlopen(url)
    soup = BeautifulSoup(text, "lxml")
    table = soup.findAll('table', attrs = {'class' : 'engineTable'})
    int_table = table[0]
    
    # iterate through all tables, find the one with caption tag
    for temp_table in table:
        caption_tag = temp_table.findAll('caption')
        if(len(caption_tag) > 0):
            int_table = temp_table
    
    # fetch table with data
    tr_list = int_table.findAll('tr', attrs = {'class': 'data1'})
    
    # populate data
    for tr in tr_list:
        td_list = tr.findAll('td')
        row_data = []
        for td in td_list:
            td_str = str(td)
            cleantext = BeautifulSoup(td_str, "lxml").get_text()
            row_data.append(cleantext)
        all_players.append(row_data)
        
    # populate column names
    tr_list_columns = int_table.findAll('tr', attrs = {'class': 'headlinks'})
    cols_count = len(tr_list_columns[0].findAll('th'))
    
    column_names_ls = []
    for i in range(cols_count):
        column_name = tr_list_columns[0].findAll('th')[i].get_text()
        column_names_ls.append(column_name)
        
    # convert to dataframe
    t20_bat_df = pd.DataFrame(all_players, columns = column_names_ls)

# %%
t20_bat_df.head()
# Out:
#                   Player       Span  Mat Inns  NO  Runs   HS    Ave    BF  \
# 0        V Kohli (INDIA)  2010-2021   90   84  24  3159  94*  52.65  2272
# 1        MJ Guptill (NZ)  2009-2021  102   98   7  2939  105  32.29  2148
# 2      RG Sharma (INDIA)  2007-2021  111  103  15  2864  118  32.54  2061
# 3  Mohammad Hafeez (PAK)  2006-2021  106   99  11  2388  99*  27.13  1978
# 4         AJ Finch (AUS)  2011-2021   71   71  10  2346  172  38.45  1542
#
#        SR 100  50  0   4s   6s
# 0  139.04   0  28  3  285   90
# 1  136.82   2  17  3  256  147
# 2  138.96   4  22  6  252  133
# 3  120.72   0  14  7  240   71
# 4  152.14   2  14  5  235  104

# %%
len(df)
# Out:
# 2193

# %% [markdown]
# ## ODI - Batting Stats - By Players

# %%
# find pages count, using page 1 as reference
url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=" + str(1) + ";template=results;type=batting"
text = urlopen(url)
soup = BeautifulSoup(text, "lxml")
table = soup.findAll('table', attrs = {'class' : 'engineTable'})

tr_list = table[1].findAll('tr', attrs = {'class': 'data2'})

min_pages = int(tr_list[0].findAll('b')[0].get_text())
max_pages = int(tr_list[0].findAll('b')[1].get_text())

entries_per_page = int(tr_list[0].findAll('b')[3].get_text())
total_players_count = int(tr_list[0].findAll('b')[4].get_text())

# set limits to run the for loop
min_limit = min_pages
if (total_players_count//entries_per_page) > 0:
    max_limit = max_pages + 1

# initialize all players data
all_players = []

for k in range(min_limit, max_limit):
    # url to text & then to soup object conversion
    url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=" + str(k) + ";template=results;type=batting"
    text = urlopen(url)
    soup = BeautifulSoup(text, "lxml")
    table = soup.findAll('table', attrs = {'class' : 'engineTable'})
    int_table = table[0]
    
    # iterate through all tables, find the one with caption tag
    for temp_table in table:
        caption_tag = temp_table.findAll('caption')
        if(len(caption_tag) > 0):
            int_table = temp_table
    
    # fetch table with data
    tr_list = int_table.findAll('tr', attrs = {'class': 'data1'})
    
    # populate data
    for tr in tr_list:
        td_list = tr.findAll('td')
        row_data = []
        for td in td_list:
            td_str = str(td)
            cleantext = BeautifulSoup(td_str, "lxml").get_text()
            row_data.append(cleantext)
        all_players.append(row_data)
        
    # populate column names
    tr_list_columns = int_table.findAll('tr', attrs = {'class': 'headlinks'})
    cols_count = len(tr_list_columns[0].findAll('th'))
    
    column_names_ls = []
    for i in range(cols_count):
        column_name = tr_list_columns[0].findAll('th')[i].get_text()
        column_names_ls.append(column_name)
        
    # convert to dataframe
    odi_bat_df = pd.DataFrame(all_players, columns = column_names_ls)

# %%
odi_bat_df.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0
# 0  21368  86.23  49  96  20
# 1  18048  78.86  25  93  15
# 2  17046  80.39  30  82  20
# 3  14725  91.20  28  68  34
# 4  16020  78.96  19  77  28

# %%
len(odi_bat_df)
# Out:
# 2652
