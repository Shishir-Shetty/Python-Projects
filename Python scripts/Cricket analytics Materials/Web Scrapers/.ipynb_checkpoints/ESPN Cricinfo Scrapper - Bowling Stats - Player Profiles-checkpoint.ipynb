# %% [markdown]
# ## Imports

# %%
# to convert into dataframes
import pandas as pd

# extract url response/info
from urllib.request import urlopen

# to work with html content
from bs4 import BeautifulSoup

# %% [markdown]
# ## T20I - Bowling Stats - By Players

# %%
# find pages count, using page 1 as reference
url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=" + str(1) + ";template=results;type=bowling"
text = urlopen(url)
soup = BeautifulSoup(text, "lxml")
table = soup.findAll('table', attrs = {'class' : 'engineTable'})

tr_list = table[1].findAll('tr', attrs = {'class': 'data2'})

min_pages = int(tr_list[0].findAll('b')[0].get_text())
max_pages = int(tr_list[0].findAll('b')[1].get_text())

entries_per_page = int(tr_list[0].findAll('b')[3].get_text())
total_players_count = int(tr_list[0].findAll('b')[4].get_text())

# set limits to run the for loop
min_limit = min_pages
if (total_players_count//entries_per_page) > 0:
    max_limit = max_pages + 1

# initialize all players data
all_players = []

for k in range(min_limit, max_limit):
    # url to text & then to soup object conversion
    url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=" + str(k) + ";template=results;type=bowling"
    text = urlopen(url)
    soup = BeautifulSoup(text, "lxml")
    table = soup.findAll('table', attrs = {'class' : 'engineTable'})
    int_table = table[0]
    
    # iterate through all tables, find the one with caption tag
    for temp_table in table:
        caption_tag = temp_table.findAll('caption')
        if(len(caption_tag) > 0):
            int_table = temp_table
    
    # fetch table with data
    tr_list = int_table.findAll('tr', attrs = {'class': 'data1'})
    
    # populate data
    for tr in tr_list:
        td_list = tr.findAll('td')
        row_data = []
        for td in td_list:
            td_str = str(td)
            cleantext = BeautifulSoup(td_str, "lxml").get_text()
            row_data.append(cleantext)
        all_players.append(row_data)
        
    # populate column names
    tr_list_columns = int_table.findAll('tr', attrs = {'class': 'headlinks'})
    cols_count = len(tr_list_columns[0].findAll('th'))
    
    column_names_ls = []
    for i in range(cols_count):
        column_name = tr_list_columns[0].findAll('th')[i].get_text()
        column_names_ls.append(column_name)
        
    # convert to dataframe
    t20_bowl_df = pd.DataFrame(all_players, columns = column_names_ls)

# %%
t20_bowl_df.head()
# Out:
#                     Player       Span Mat Inns  Overs Mdns  Runs Wkts   BBI  \
# 0          SL Malinga (SL)  2006-2020  84   83  299.5    1  2225  107   5/6
# 1          TG Southee (NZ)  2008-2021  83   81  297.0    2  2492   99  5/18
# 2  Shahid Afridi (ICC/PAK)  2006-2018  99   97  361.2    4  2396   98  4/11
# 3    Rashid Khan (AFG/ICC)  2015-2021  51   51  193.0    1  1200   95   5/3
# 4  Shakib Al Hasan (BDESH)  2006-2019  76   75  277.5    2  1894   92  5/20
#
#      Ave  Econ    SR  4  5
# 0  20.79  7.42  16.8  1  2
# 1  25.17  8.39  18.0  1  1
# 2  24.44  6.63  22.1  3  0
# 3  12.63  6.21  12.1  3  2
# 4  20.58  6.81  18.1  3  1

# %%
len(t20_bowl_df)
# Out:
# 2193

# %% [markdown]
# ## ODI - Bowling Stats - By Players

# %%
# find pages count, using page 1 as reference
url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=" + str(1) + ";template=results;type=bowling"
text = urlopen(url)
soup = BeautifulSoup(text, "lxml")
table = soup.findAll('table', attrs = {'class' : 'engineTable'})

tr_list = table[1].findAll('tr', attrs = {'class': 'data2'})

min_pages = int(tr_list[0].findAll('b')[0].get_text())
max_pages = int(tr_list[0].findAll('b')[1].get_text())

entries_per_page = int(tr_list[0].findAll('b')[3].get_text())
total_players_count = int(tr_list[0].findAll('b')[4].get_text())

# set limits to run the for loop
min_limit = min_pages
if (total_players_count//entries_per_page) > 0:
    max_limit = max_pages + 1

# initialize all players data
all_players = []

for k in range(min_limit, max_limit):
    # url to text & then to soup object conversion
    url = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=" + str(k) + ";template=results;type=bowling"
    text = urlopen(url)
    soup = BeautifulSoup(text, "lxml")
    table = soup.findAll('table', attrs = {'class' : 'engineTable'})
    int_table = table[0]
    
    # iterate through all tables, find the one with caption tag
    for temp_table in table:
        caption_tag = temp_table.findAll('caption')
        if(len(caption_tag) > 0):
            int_table = temp_table
    
    # fetch table with data
    tr_list = int_table.findAll('tr', attrs = {'class': 'data1'})
    
    # populate data
    for tr in tr_list:
        td_list = tr.findAll('td')
        row_data = []
        for td in td_list:
            td_str = str(td)
            cleantext = BeautifulSoup(td_str, "lxml").get_text()
            row_data.append(cleantext)
        all_players.append(row_data)
        
    # populate column names
    tr_list_columns = int_table.findAll('tr', attrs = {'class': 'headlinks'})
    cols_count = len(tr_list_columns[0].findAll('th'))
    
    column_names_ls = []
    for i in range(cols_count):
        column_name = tr_list_columns[0].findAll('th')[i].get_text()
        column_names_ls.append(column_name)
        
    # convert to dataframe
    odi_bowl_df = pd.DataFrame(all_players, columns = column_names_ls)

# %%
odi_bowl_df.head()
# Out:
#                          Player       Span  Mat Inns  Balls   Runs Wkts   BBI  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811  12326  534  7/30
# 1             Wasim Akram (PAK)  1984-2003  356  351  18186  11812  502  5/15
# 2            Waqar Younis (PAK)  1989-2003  262  258  12698   9919  416  7/36
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322  320  15775  11014  400  8/19
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398  372  17670  13632  395  7/12
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# 4  34.51  4.62  44.7   4   9

# %%
len(odi_bowl_df)
# Out:
# 2652
